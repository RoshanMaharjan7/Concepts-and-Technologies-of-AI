# %% [markdown]
# <a href="https://colab.research.google.com/github/RoshanMaharjan7/Concepts-and-Technologies-of-AI/blob/main/2408424_Roshan_Maharjan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Student Name: Roshan Maharjan\
# Student ID: 2408424

# %% [markdown]
# #3 Tasks - To - Do:
# Please Solve all the Problems as instructed:

# %%
# Imports Required for this assignment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up
# Exercises:

# %% [markdown]
# 1. Data Exploration and Understanding:

# %% [markdown]
# • Dataset Overview:
# 1. Load the dataset and display the first 10 rows.

# %%
# Reading CSV
df = pd.read_csv('/content/drive/MyDrive/Concepts of AI/Assignment1/WHR-2024-5CS037.csv')

# Printing the first 10 rows.
print("The first 10 countries in the dataset:")
df.head(10)
# Out:
# The first 10 countries in the dataset:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
df.describe()
# Out:
#             score  Log GDP per capita  Social support  \
# count  143.000000          140.000000      140.000000
# mean     5.527580            1.378807        1.134329
# std      1.170717            0.425098        0.333317
# min      1.721000            0.000000        0.000000
# 25%      4.726000            1.077750        0.921750
# 50%      5.785000            1.431500        1.237500
# 75%      6.416000            1.741500        1.383250
# max      7.741000            2.141000        1.617000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               140.000000                    140.000000  140.000000
# mean                  0.520886                      0.620621    0.146271
# std                   0.164923                      0.162492    0.073441
# min                   0.000000                      0.000000    0.000000
# 25%                   0.398000                      0.527500    0.091000
# ...

# %% [markdown]
# 2. Identify the number of rows and columns in the dataset.

# %%
# Displaying the number of rows and columns available in this dataset
rows, columns = df.shape
print("Number of rows:", rows)
print("Number of columns:", columns)
# Out:
# Number of rows: 143
# Number of columns: 9

# %% [markdown]
# 3. List all the columns and their data types.

# %%
# Displaying data types of all the columns available in this dataset
print("Data types of all columns:")
print(df.dtypes)
# Out:
# Data types of all columns:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# • Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.

# %%
# Selecting column score from the dataframe
score_column = df['score']

# Calculating and displaying mean, median and standard deviation of column score
print("Mean of score = ", score_column.mean())
print("Median of score = ",score_column.median())
print("Standard deviation of score = ",score_column.std())
# Out:
# Mean of score =  5.52758041958042
# Median of score =  5.785
# Standard deviation of score =  1.1707165099442995

# %% [markdown]
# 2. Identify the country with the highest and lowest happiness scores.

# %%
# Finding the country with the highest score
highest_happiness_country = df.loc[df['score'].idxmax()]
# Displaying the name of country with the highest score
print("Country with highest happiness score:", highest_happiness_country['Country name'])

# Finding the country with the lowest score
lowest_happiness_country = df.loc[df['score'].idxmin()]
# Displaying the name of country with the lowest score
print("Country with lowest happiness score:", lowest_happiness_country['Country name'])
# Out:
# Country with highest happiness score: Finland
# Country with lowest happiness score: Afghanistan

# %% [markdown]
# • Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
# Calculating the sum of null values in all the columns
null_values_df = df.isnull().sum()
print("Columns and their number of null values : ")
print(null_values_df)
# Out:
# Columns and their number of null values :
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# Working out null values

# %%
# dropping null values
df.dropna(axis=0, how='any', inplace=True)

print("Missing values count after fixing null values:")
print(df.isnull().sum())
# Out:
# Missing values count after fixing null values:
# Country name                    0
# score                           0
# Log GDP per capita              0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# Dystopia + residual             0
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.

# %%
# Filtering the data with the score higher than 7.5
filtered_df = df[df['score'] > 7.5]
print("Filtered dataframe with countries higher than 7.5 score:")
filtered_df
# Out:
# Filtered dataframe with countries higher than 7.5 score:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %% [markdown]
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
# Sorting the filtered_df by GDP per capita in descending order
print("The filtered data in descending order respect to GDP: ")
sorted_df = filtered_df.sort_values(by='Log GDP per capita', ascending=False)
sorted_df.head(10)
# Out:
# The filtered data in descending order respect to GDP:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# • Adding New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)\
# Medium − (4 ≤ Score ≤ 6)\
# High − (Score > 6)

# %%
# Return value according to the score
def categorize_happiness(score):
    if score < 4:
        return 'Low'
    elif 4 <= score <= 6:
        return 'Medium'
    else:
        return 'High'

# Adding a new Column Happiness Category to the dataframe
df['Happiness Category'] = df['score'].apply(categorize_happiness)
# Display
print("The dataframe after adding Happiness Category Column: ")
df
# Out:
# The dataframe after adding Happiness Category Column:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# 2. Data Visualizations:\
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
# Sorting the dataframe by score column in descending order to find the top 10 highest score countries
happiest_countries = df.sort_values(by='score', ascending=False).head(10)

# Colors
colors = ['#1f77b4', '#2ca02c', '#d62728', '#17becf', '#9467bd', '#ff7f0e', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22']

# Plotting the bar graph
plt.figure(figsize=(12, 6))
plt.bar(happiest_countries['Country name'], happiest_countries['score'], color=colors)
plt.title("Top 10 Happiest Countries Scores")
plt.xlabel("Countries")
plt.ylabel("Happiness Score")
plt.show()

# %% [markdown]
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
# Sorting the dataframe by score column in ascending order to find top 10 lowest score countries
unhappiest_countries = df.sort_values(by='score', ascending=True).head(10)

# Ploting the line graph
plt.figure(figsize=(14, 6))
plt.plot(unhappiest_countries['Country name'], unhappiest_countries['score'], marker='o', linestyle='-', color='blue')
plt.title("Top 10 Unhappiest Countries Scores")
plt.xlabel("Countries")
plt.ylabel("Happiness Score")
plt.show()

# %% [markdown]
# • Plot a histogram for the Score column to show its distribution and also interpret.

# %%
# Ploting histogram to show distribution of score in the datafram
plt.figure(figsize=(10, 6))
sns.histplot(df['score'],bins=20, kde=True, color='#1f77b4')
plt.title('Distribution of Happiness Scores')
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
# Selecting Log GDP per capita and score column from the dataframe
data_scatter_plot = df[['Log GDP per capita', 'score']]

# Scatter Ploting the data GDP vs Score
data_scatter_plot.plot(kind='scatter', x='Log GDP per capita', y='score', title='Log GDP per capita vs Score', edgecolor='black' )
plt.xlabel('Log GDP per capita', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.show()

# %% [markdown]
# #3.2 Problem - 2 - Some Advance Data Exploration Task:

# %% [markdown]
# ##Task - 1 - Setup Task - Preparing the South-Asia Dataset:

# %% [markdown]
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Srilanka"]

# %%
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Sri Lanka"]

# %% [markdown]
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}

# %%
# Filtering the dataframe with the available south asian countries
filtered_df = df[df['Country name'].isin(south_asian_countries)]
print("The dataset of south asian countries:")
filtered_df
# Out:
# The dataset of south asian countries:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
# Writitng the filtered south asian data to a new csv file
filtered_df.to_csv('/content/drive/MyDrive/Concepts of AI/Assignment1/south_asian_countries.csv', index=False)

# %% [markdown]
# ##Task - 2 - Composite Score Ranking:

# %% [markdown]
# Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy

# %%
# Reading the data from south_asian_countries.csv
south_asian_df = pd.read_csv('/content/drive/MyDrive/Concepts of AI/Assignment1/south_asian_countries.csv')

# Calculating the composite score
composite_score = 0.40 * south_asian_df['Log GDP per capita'] + 0.30 * south_asian_df['Social support']  + 0.30 * south_asian_df['Healthy life expectancy']
# Adding a new column to the dataframe
south_asian_df['Composite Score'] = composite_score
print("South Asian dataset with new column Composite Score:")
south_asian_df
# Out:
# South Asian dataset with new column Composite Score:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 2. Rank the South Asian countries based on the Composite Score in descending order.

# %%
# Sorting value by Composite Score column
sorted_south_asian_df = south_asian_df.sort_values(by="Composite Score", ascending=False)
print("South Asian Countries sorted in descending order with respect to Composite Score:")
sorted_south_asian_df
# Out:
# South Asian Countries sorted in descending order with respect to Composite Score:
#   Country name  score  Log GDP per capita  Social support  \
# 3    Sri Lanka  3.898               1.361           1.179
# 0        Nepal  5.158               0.965           0.990
# 2        India  4.054               1.166           0.653
# 1     Pakistan  4.657               1.069           0.600
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 3                    0.586                         0.583       0.144
# 0                    0.443                         0.653       0.209
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 4                    0.513                         0.775       0.140
# ...

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.

# %%
# Taking the top 5 data out of sorted_south_asian_df
top_countries = sorted_south_asian_df.head(5)

# Colors
colors = ['#1f77b4', '#2ca02c', '#17becf', '#9467bd', '#ff7f0e', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22']

# Plotting the horizontal bar graph
plt.figure(figsize=(12, 6))
plt.barh(top_countries['Country name'], top_countries['Composite Score'], color=colors)
plt.title("Top 5 South Asian Countries for Composite Score", fontsize=14)
plt.xlabel("Composite Score", fontsize=12)
plt.ylabel("Countries", fontsize=12)
plt.show()

# %% [markdown]
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
south_asian_df['Composite Rank'] = south_asian_df['Composite Score'].rank(ascending=False)
south_asian_df['Score Rank'] = south_asian_df['score'].rank(ascending=False)

score_composite_df = south_asian_df[['Country name', 'Composite Rank', 'Score Rank']].melt(id_vars=['Country name'],
                                                                                      value_vars=['Composite Rank', 'Score Rank'],
                                                                                      var_name='Rank Type',
                                                                                      value_name='Rank')

sns.barplot(x='Country name', y='Rank', hue='Rank Type', data=score_composite_df, palette='viridis')

plt.title('Ranking Comparison between Score and Composite Score')
plt.xlabel('Country')
plt.ylabel('Rank')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.show()

# %% [markdown]
# ##Task - 3 - Outlier Detection:

# %% [markdown]
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.

# %%
# Calculating the IQR for score
score_Q1 = south_asian_df['score'].quantile(0.25)
score_Q3 = south_asian_df['score'].quantile(0.75)
score_IQR = score_Q3 - score_Q1

# Calculating the IQR for GDP
GDP_Q1 = south_asian_df['Log GDP per capita'].quantile(0.25)
GDP_Q3 = south_asian_df['Log GDP per capita'].quantile(0.75)
GDP_IQR = GDP_Q3 - GDP_Q1

# Calculating lower and higher bound for score
lower_bound_score = score_Q1 - 1.5 * score_IQR
higher_bound_score = score_Q3 + 1.5 * score_IQR

# Calculating lower and higher bound for GDP
lower_bound_GDP = GDP_Q1 - 1.5 * GDP_IQR
higher_bound_GDP = GDP_Q3 + 1.5 * GDP_IQR

# Finding the outliers from the dataset
outliers = south_asian_df[(south_asian_df['score'] < lower_bound_score ) | (south_asian_df['score'] > higher_bound_score) |
                         (south_asian_df['Log GDP per capita'] < lower_bound_GDP) | (south_asian_df['Log GDP per capita'] > higher_bound_GDP)]

# Display
print("Outliers in the South Asian dataset:")
outliers
# Out:
# Outliers in the South Asian dataset:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628             0.0
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                           0.0       0.091
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 5                      0.088                0.672                Low
#
#    Composite Score  Composite Rank  Score Rank
# 5           0.3238             6.0         6.0

# %% [markdown]
# 2. Define outliers using the 1.5 × IQR rule.

# %% [markdown]
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.

# %%
# Ploting the scatter plot graph of GDP vs score of South Asian Countries
plt.figure(figsize=(8, 6))
plt.scatter(south_asian_df['Log GDP per capita'], south_asian_df['score'], color='blue', label='Standard')
plt.scatter(outliers['Log GDP per capita'], outliers['score'], color='red', label='Outliers')
plt.xlabel('Log GDP per capita')
plt.ylabel('Score')
plt.title('GDP vs Score for South Asian Countries and Outliers')
plt.legend()
plt.show()

# %% [markdown]
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %% [markdown]
# ##Task - 4 - Exploring Trends Across Metrics:

# %% [markdown]
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.

# %%
# Calculating the correlation for score vs freedom and score vs generosity
correlation_score_freedom = south_asian_df['score'].corr(south_asian_df['Freedom to make life choices'])
correlation_score_generosity = south_asian_df['score'].corr(south_asian_df['Generosity'])

# Displaying result
print("Correlation with Freedom to Make Life Choices:", correlation_score_freedom)
print("Correlation with Generosity:", correlation_score_generosity)
# Out:
# Correlation with Freedom to Make Life Choices: 0.8005185224163315
# Correlation with Generosity: 0.874512371253192

# %% [markdown]
# 2. Create scatter plots with trendlines for these metrics against the Score.

# %%
# Ploting the scatterplot graph
plt.figure(figsize=(18, 6))

plt.subplot(1,2,1)
sns.scatterplot(x="Freedom to make life choices", y="score", data=south_asian_df, color='blue', label='Freedom to Make Life Choices')
sns.regplot(x="Freedom to make life choices", y="score", data=south_asian_df, scatter=False, color='red')
plt.title("Scatter Plot with Trendline for Freedom to Make Life Choices")
plt.xlabel("Freedom to make life choices")
plt.ylabel("Score")

plt.subplot(1,2,2)
sns.scatterplot(x="Generosity", y="score", data=south_asian_df, color='blue', label='Generosity')
sns.regplot(x="Generosity", y="score", data=south_asian_df, scatter=False, color='red')
plt.title("Scatter Plot with Trendline for Generosity")
plt.xlabel("Generosity")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %% [markdown]
# ##Task - 5 - Gap Analysis:

# %% [markdown]
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.

# %%
# Adding new column GDP-Score Gap to the south_asian_df
GDP_score_gap = south_asian_df['Log GDP per capita'] - south_asian_df['score']
south_asian_df['GDP-Score Gap'] = GDP_score_gap
print("South asian data set with new column GDP-Score Gap: ")
south_asian_df
# Out:
# South asian data set with new column GDP-Score Gap:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
# arranging the dataframe in ascending order respect to gap
ascending_gap_df = south_asian_df.sort_values(by='GDP-Score Gap', ascending=True)
# arranging the dataframe in descending order respect to gap
descending_gap_df = south_asian_df.sort_values(by='GDP-Score Gap', ascending=False)

# Displaying result
print("South Asian Countries by GDP-Score gap in ascending order:")
print(ascending_gap_df)

print("\n\nSouth Asian Countries by GDP-Score gap in descending order:")
print(descending_gap_df)
# Out:
# South Asian Countries by GDP-Score gap in ascending order:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 4   Bangladesh  3.886               1.122           0.249
# 3    Sri Lanka  3.898               1.361           1.179
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 4                    0.513                         0.775       0.140
# 3                    0.586                         0.583       0.144
# 5                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.

# %%
# Selecting the top 3 positive and negative gaps from the datafram
top_positive_gap_countries = descending_gap_df.head(3)
top_negative_gap_countries = ascending_gap_df.head(3)

# Colors
colors = ['#1f77b4', '#2ca02c', '#17becf', '#9467bd', '#ff7f0e', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22']

# Ploting bar graph
plt.figure(figsize=(14, 6))

plt.subplot(1,2,1)
plt.title("Top 3 Countries with Largest Positive GDP-Score Gap")
plt.xlabel("Country")
plt.ylabel("GDP-Score Gap")
plt.bar(top_positive_gap_countries['Country name'], top_positive_gap_countries['GDP-Score Gap'], color=colors, label='Top 3 Positive GDP-Score Gap')

plt.subplot(1,2,2)
plt.title("Top 3 Countries with Negative GDP-Score Gap")
plt.xlabel("Country")
plt.ylabel("GDP-Score Gap")
plt.bar(top_negative_gap_countries['Country name'], top_negative_gap_countries['GDP-Score Gap'], color=colors, label='Top 3 Negative GDP-Score Gap')

plt.show()

# %% [markdown]
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %% [markdown]
# #3.3 Problem - 3 - Comparative Analysis:

# %% [markdown]
# ##Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:

# %% [markdown]
# Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]

# %%
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan","Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]

# Filtering the dataframe with the available middle_east_countries
middle_east_df = df[df['Country name'].isin(middle_east_countries)]
print("The Middle East dataset: ")
middle_east_df
# Out:
# The Middle East dataset:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# 12                     0.661                         0.827       0.200
# ...

# %% [markdown]
# Complete the following task:
# ###1. Descriptive Statistics:

# %% [markdown]
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.

# %%
# Calculating mean and standard deviation for south asian countries with respect to score
south_asia_mean = south_asian_df['score'].mean()
south_asia_std = south_asian_df['score'].std()

# Calculating mean and standard deviation for middle east countries with respect to score
middle_east_mean = middle_east_df['score'].mean()
middle_east_std = middle_east_df['score'].std()

print("South Asia Score Mean:", south_asia_mean)
print("South Asia Score Standard Deviation:", south_asia_std)
print("\nMiddle East Score Mean:", middle_east_mean)
print("Middle East Score Standard Deviation:", middle_east_std)
# Out:
# South Asia Score Mean: 3.895666666666667
# South Asia Score Standard Deviation: 1.1770690152521504
#
# Middle East Score Mean: 5.351333333333333
# Middle East Score Standard Deviation: 1.648656346847335

# %% [markdown]
# • Which region has higher happiness Scores on average?

# %%
# Display with region has higher happiness score on average
if(south_asia_mean > middle_east_mean):
  print("South Asian Countries has higher average happiness score compared to Middle East Countries")
elif(middle_east_mean > south_asia_mean):
  print("Middle East Countries has higher average happiness score compared to South Asian Countries")
else:
  print("Countries of both region have similar average happiness score")
# Out:
# Middle East Countries has higher average happiness score compared to South Asian Countries

# %% [markdown]
# ###2. Top and Bottom Performers:

# %%
# Top 3 south asian countries by score
top_south_asian_df = south_asian_df.sort_values(by='score', ascending=False).head(3)
# Bottom 3 south asian countries by score
bottom_south_asian_df = south_asian_df.sort_values(by='score', ascending=True).head(3)

# Top 3 middle east countries by score
top_middle_east_df = middle_east_df.sort_values(by='score', ascending=False).head(3)
# Bottom 3 middle east countries by score
bottom_middle_east_df = middle_east_df.sort_values(by='score', ascending=True).head(3)

# Display output
print("Top South Asian Countries respect to Happiness Score are:\n")
print(top_south_asian_df)
print("\nBottom South Asian Countries respect to Happiness Score are:\n")
print(bottom_south_asian_df)
print("\nTop Middle East Countries respect to Happiness Score are:\n")
print(top_middle_east_df)
print("\nBottom Middle East Countries respect to Happiness Score are:\n")
print(bottom_middle_east_df)
# Out:
# Top South Asian Countries respect to Happiness Score are:
#
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 0                      0.115                1.783             Medium
# 1                      0.074                1.907             Medium
# 2                      0.122                0.756             Medium
#
#    Composite Score  Composite Rank  Score Rank  GDP-Score Gap
# ...

# %% [markdown]
# • Plot bar charts comparing these charts.

# %%
# Ploting the top and bottom 3 countries from south asia and middle east with respect to score
plt.figure(figsize=(20, 6))

# South Asian plot
plt.subplot(1, 2, 1)
plt.bar(top_south_asian_df['Country name'], top_south_asian_df['score'], color='#2ca02c', label='Top South Asian Countries')
plt.bar(bottom_south_asian_df['Country name'], bottom_south_asian_df['score'], color='#ff7f0e', label='Bottom South Asian Countries')
plt.title("Top and Bottom South Asian Countries by Happiness Score")
plt.xlabel("Countries")
plt.ylabel("Score")
plt.legend()

# Middle East plot
plt.subplot(1, 2, 2)
plt.bar(top_middle_east_df['Country name'], top_middle_east_df['score'], color='#2ca02c', label='Top Middle East Countries')
plt.bar(bottom_middle_east_df['Country name'], bottom_middle_east_df['score'], color='#ff7f0e', label='Bottom Middle East Countries')
plt.title("Top and Bottom Middle East Countries by Happiness Score")
plt.xlabel("Countries")
plt.ylabel("Score")
plt.legend()

# %% [markdown]
# ###3. Metric Comparisons:

# %% [markdown]
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.

# %%
plt.figure(figsize=(10, 6))

# Calculating mean from both region
GDP_south_asian_df = south_asian_df['Log GDP per capita'].mean()
GDP_middle_east_df = middle_east_df['Log GDP per capita'].mean()

# Calculating mean from both region
social_support_south_asian_df = south_asian_df['Social support'].mean()
social_support_middle_east_df = middle_east_df['Social support'].mean()

# Calculating mean from both region
healthy_life_expectancy_south_asian_df = south_asian_df['Healthy life expectancy'].mean()
healthy_life_expectancy_middle_east_df = middle_east_df['Healthy life expectancy'].mean()

# for plotting
labels = ['GDP', 'Social Support', 'Healthy Life Expectancy']
south_asian_means = [GDP_south_asian_df, social_support_south_asian_df, healthy_life_expectancy_south_asian_df]
middle_east_means = [GDP_middle_east_df, social_support_middle_east_df, healthy_life_expectancy_middle_east_df]

# For labels
x = np.arange(len(labels))
width = 0.35

# Ploting for both regions
plt.bar(x - width/2, south_asian_means, width, label='South Asia', color='#2ca02c')
plt.bar(x + width/2, middle_east_means, width, label='Middle East', color='#ff7f0e')

plt.title("Comparison between South Asia and Middle East")
plt.xlabel("Metric")
plt.ylabel("Average Value")
plt.xticks(x, labels)
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# • Which metrics show the largest disparity between the two regions?

# %%
# Calculating the absolute difference between the means of each metric for the two regions.
gdp_diff = abs(GDP_south_asian_df - GDP_middle_east_df)
social_support_diff = abs(social_support_south_asian_df - social_support_middle_east_df)
health_diff = abs(healthy_life_expectancy_south_asian_df - healthy_life_expectancy_middle_east_df)


# Finding the metric with the largest difference
largest_disparity_metric = max(gdp_diff, social_support_diff, health_diff)

# Display Result
if largest_disparity_metric == gdp_diff:
    print("GDP per capita shows the largest disparity between the two regions.")
elif largest_disparity_metric == social_support_diff:
    print("Social support shows the largest disparity between the two regions.")
else:
    print("Healthy life expectancy shows the largest disparity between the two regions.")
# Out:
# Social support shows the largest disparity between the two regions.

# %% [markdown]
# ###4. Happiness Disparity:

# %% [markdown]
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.\
# • Which region has greater variability in happiness?

# %%
# Calculating the range and coefficient of variation(cv) for score in South Asia
south_asia_score_range = south_asian_df['score'].max() - south_asian_df['score'].min()
south_asia_score_cv = (south_asian_df['score'].std() / south_asian_df['score'].mean())*100

# Calculating the range and coefficient of variation(cv) for score in the Middle East
middle_east_score_range = middle_east_df['score'].max() - middle_east_df['score'].min()
middle_east_score_cv = (middle_east_df['score'].std() / middle_east_df['score'].mean())*100

print("South Asia score range = ", south_asia_score_range)
print(f"South Asia score CV = {south_asia_score_cv:.2f}%")
print("\nMiddle East score range = ", middle_east_score_range)
print(f"Middle East score CV = {middle_east_score_cv:.2f}%")


print(f"\nSince South Asia has higher coefficient of variation {south_asia_score_cv:.2f}%, South Asia has greater variability in happiness than Middle East.")
# Out:
# South Asia score range =  3.4370000000000003
# South Asia score CV = 30.21%
#
# Middle East score range =  4.634
# Middle East score CV = 30.81%
#
# Since South Asia has higher coefficient of variation 30.21%, South Asia has greater variability in happiness than Middle East.

# %% [markdown]
# ###5. Correlation Analysis:

# %% [markdown]
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.

# %%
# Calculating the correlation of score with freedom and generosity for south asian countries
south_asia_score_freedom = south_asian_df['score'].corr(south_asian_df['Freedom to make life choices'])
south_asia_score_generosity = south_asian_df['score'].corr(south_asian_df['Generosity'])

# Calculating the correlation of score with freedom and generosity for the middle east countries
middle_east_score_freedom = middle_east_df['score'].corr(middle_east_df['Freedom to make life choices'])
middle_east_score_generosity = middle_east_df['score'].corr(middle_east_df['Generosity'])

print("Correlation between Score and Freedom to Make Life Choices in South Asia:", south_asia_score_freedom)
print("Correlation between Score and  Freedom to Make Life Choices in Middle East:", middle_east_score_freedom)
print("\nCorrelation between Score and Generosity in South Asia:", south_asia_score_generosity)
print("Correlation between Score and Generosity in Middle East:", middle_east_score_generosity)
# Out:
# Correlation between Score and Freedom to Make Life Choices in South Asia: 0.8005185224163315
# Correlation between Score and  Freedom to Make Life Choices in Middle East: 0.8632202433827544
#
# Correlation between Score and Generosity in South Asia: 0.874512371253192
# Correlation between Score and Generosity in Middle East: 0.6275236536964182

# %% [markdown]
# • Create scatter plots to visualize and interpret the relationships.

# %%
# Ploting the scatterplot to show the above interpretation
plt.figure(figsize=(10, 6))
sns.scatterplot(x="score", y="Freedom to make life choices", data=south_asian_df, color='blue', label='South Asian Countries')
sns.scatterplot(x="score", y="Freedom to make life choices", data=middle_east_df, color='green', label='Middle East Countries')
plt.title("Freedom to Make Life Choices vs Score (South Asia vs Middle East)")
plt.xlabel("Score")
plt.ylabel("Freedom to Make Life Choices");

# %%
# Ploting the generosity vs score scatterplot
plt.figure(figsize=(10,6))
sns.scatterplot(x="score", y="Generosity", data=south_asian_df, color='blue', label='South Asian Countries')
sns.scatterplot(x="score", y="Generosity", data=middle_east_df, color='green', label='Middle East Countries')
plt.title("Generosity vs Score (South Asia vs Middle East)")
plt.xlabel("Score")
plt.ylabel("Generosity");

# %% [markdown]
# ###6. Outlier Detection:

# %% [markdown]
# • Identify outlier countries in both regions based on Score and GDP per Capita.

# %%
# SOUTH ASIA OUTLIERS
south_asia_score_Q1 = south_asian_df['score'].quantile(0.25)
south_asia_score_Q3 = south_asian_df['score'].quantile(0.75)
south_asia_score_IQR = south_asia_score_Q3 - south_asia_score_Q1

south_asia_GDP_Q1 = south_asian_df['Log GDP per capita'].quantile(0.25)
south_asia_GDP_Q3 = south_asian_df['Log GDP per capita'].quantile(0.75)
south_asia_GDP_IQR = south_asia_GDP_Q3 - south_asia_GDP_Q1

south_asia_lower_bound_score = south_asia_score_Q1 - 1.5 * south_asia_score_IQR
south_asia_higher_bound_score = south_asia_score_Q3 + 1.5 * south_asia_score_IQR

south_asia_lower_bound_GDP = south_asia_GDP_Q1 - 1.5 * south_asia_GDP_IQR
south_asia_higher_bound_GDP = south_asia_GDP_Q3 + 1.5 * south_asia_GDP_IQR

south_asia_outliers = south_asian_df[(south_asian_df['score'] < south_asia_lower_bound_score) | (south_asian_df['score'] > south_asia_higher_bound_score) | (south_asian_df['Log GDP per capita'] < south_asia_lower_bound_GDP) | (south_asian_df['Log GDP per capita'] > south_asia_higher_bound_GDP)]

print("South Asia Outliers based on Score and GDP per Capita:")
print(south_asia_outliers)



# MIDDLE EAST OUTLIERS
middle_east_score_Q1 = middle_east_df['score'].quantile(0.25)
middle_east_score_Q3 = middle_east_df['score'].quantile(0.75)
middle_east_score_IQR = middle_east_score_Q3 - middle_east_score_Q1

middle_east_GDP_Q1 = middle_east_df['Log GDP per capita'].quantile(0.25)
middle_east_GDP_Q3 = middle_east_df['Log GDP per capita'].quantile(0.75)
middle_east_GDP_IQR = middle_east_GDP_Q3 - middle_east_GDP_Q1

middle_east_lower_bound_score = middle_east_score_Q1 - 1.5 * middle_east_score_IQR
middle_east_higher_bound_score = middle_east_score_Q3 + 1.5 * middle_east_score_IQR

middle_east_lower_bound_GDP = middle_east_GDP_Q1 - 1.5 * middle_east_GDP_IQR
middle_east_higher_bound_GDP = middle_east_GDP_Q3 + 1.5 * middle_east_GDP_IQR

middle_east_outliers = middle_east_df[(middle_east_df['score'] < middle_east_lower_bound_score) | (middle_east_df['score'] > middle_east_higher_bound_score) | (middle_east_df['Log GDP per capita'] < middle_east_lower_bound_GDP) | (middle_east_df['Log GDP per capita'] > middle_east_higher_bound_GDP)]

print("\nMiddle East Outliers based on Score and GDP per Capita:")
print(middle_east_outliers)
# Out:
# South Asia Outliers based on Score and GDP per Capita:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628             0.0
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                           0.0       0.091
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 5                      0.088                0.672                Low
#
#    Composite Score  Composite Rank  Score Rank  GDP-Score Gap
# 5           0.3238             6.0         6.0         -1.093
#
# Middle East Outliers based on Score and GDP per Capita:
# Empty DataFrame
# Columns: [Country name, score, Log GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption, Dystopia + residual, Happiness Category]
# Index: []

# %% [markdown]
# • Plot these outliers and discuss their implications.

# %%
  # Ploting the outliers of both regions
  plt.figure(figsize=(18, 6))

  plt.subplot(1, 2, 1)
  plt.scatter(middle_east_df['Log GDP per capita'], middle_east_df['score'], color='blue', label='Normal Data')
  plt.scatter(middle_east_outliers['Log GDP per capita'], middle_east_outliers['score'], color='red', label='Outliers')
  plt.title("Middle East GDP vs Score Data with Outliers")
  plt.xlabel('Log GDP per capita')
  plt.ylabel('Score')
  plt.legend()

  plt.subplot(1, 2, 2)
  plt.scatter(south_asian_df['Log GDP per capita'], south_asian_df['score'], color='blue', label='Normal Data')
  plt.scatter(south_asia_outliers['Log GDP per capita'], south_asia_outliers['score'], color='red', label='Outliers')
  plt.title("South Asia GDP vs Score Data with Outliers")
  plt.xlabel('Log GDP per capita')
  plt.ylabel('Score')
  plt.legend()

  plt.show()

# %% [markdown]
# ###7. Visualization:

# %% [markdown]
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.

# %%
# Ploting boxplots for the distributaion of Score between South Asia and Middle East
plt.figure(figsize=(8, 6))
sns.boxplot(x='region', y='score', data=pd.concat([south_asian_df.assign(region='South Asia'), middle_east_df.assign(region='Middle East')]), palette={'South Asia': '#3274A1', 'Middle East': '#9467bd'})
plt.title('Distribution of Score: South Asia vs Middle East')
plt.xlabel('Region')
plt.ylabel('Score')
plt.show()
# Out:
# <ipython-input-535-e58d72e2580e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='region', y='score', data=pd.concat([south_asian_df.assign(region='South Asia'), middle_east_df.assign(region='Middle East')]), palette={'South Asia': '#3274A1', 'Middle East': '#9467bd'})
